# %% [markdown]
# ### Sistem Pendukung Keputusan - Pemilihan Kendaraan Rendah Emisi
# Metode: AHP (Analytic Hierarchy Process)
# Dataset: CO2 Emissions Canada
#
# Kriteria yang digunakan (5 kriteria):
#   - C1: CO2 Emissions (g/km)          - COST   (semakin kecil semakin baik)
#   - C2: Fuel Consumption Comb (L/100) - COST   (semakin kecil semakin baik)
#   - C3: Engine Size (L)               - COST   (semakin kecil semakin baik)
#   - C4: Fuel Consumption Hwy (L/100)  - COST   (semakin kecil semakin baik)
#   - C5: Cylinders                     - COST   (semakin kecil semakin baik)

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('CO2 Emissions_Canada.csv')
print(f"Total data: {len(data)} kendaraan")
print(f"Kolom: {data.columns.tolist()}")
data
# Out:
# Total data: 7385 kendaraan
# Kolom: ['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %%
# spk menggunakn metode AHP

# penentuan kriteria 
# 1. Emisi CO2 per km (g/km) (30%) - cost
# faktor utama kendaraan ramah lingkungan
# 2. Konsumsi bahan bakar per km (L/100km) (25%) - cost
# menentukan biaya operasional kendaraan
# 3. Ukuran Mesin (cc) (10%) - cost
# mesin besar biasanya lebih boros, dan emisi tinggi
# 4. Jumlah Silinder (5%) - cost
# semakin banyak silinder, konsumsi bbm lebih tinggi
# 5. Horsepower (hp) (15%) - benefit
# menentukan performa dan tenaga kendaraan
# 6. MPG (Miles Per Gallon) (15%) - benefit
# indikator efisiensi bahan bakar

# skala ahp 
# 1: Sama penting
# 3: Sedikit lebih penting
# 5: Lebih penting
# 7: Sangat lebih penting
# 9: Mutlak lebih penting
# 2,4,6,8: Nilai antara

# %%
import pandas as pd
import numpy as np

# %%
kriteria = [
    'Emisi CO2 per km (g/km)', 
    'Konsumsi BBM Comb (L/100km)', 
    'Konsumsi BBM Hwy (L/100km)',
    'MPG (Miles Per Gallon)',
    'Ukuran Mesin (cc)', 
    'Jumlah Silinder', 
]

tipe_kriteria = [ 'cost', 'cost', 'cost', 'benefit', 'cost', 'cost' ]

print("Kriteria yang digunakan:")
for i, kriteria_name in enumerate(kriteria, start=1):
    print(f"{i}. {kriteria_name} ({tipe_kriteria[i-1]})")
# Out:
# Kriteria yang digunakan:
# 1. Emisi CO2 per km (g/km) (cost)
# 2. Konsumsi BBM Comb (L/100km) (cost)
# 3. Konsumsi BBM Hwy (L/100km) (cost)
# 4. MPG (Miles Per Gallon) (benefit)
# 5. Ukuran Mesin (cc) (cost)
# 6. Jumlah Silinder (cost)

# %%
matriks_perbandingan = np.array([
    [1,   2,   3,   3,   5,   7],
    [1/2, 1,   2,   2,   4,   5],
    [1/3, 1/2, 1,   2,   3,   4],
    [1/3, 1/2, 1/2, 1,   3,   4],
    [1/5, 1/4, 1/3, 1/3, 1,   2],
    [1/7, 1/5, 1/4, 1/4, 1/2, 1]
    
])

df_kriteria = pd.DataFrame(np.round(matriks_perbandingan, 2), columns=kriteria, index=kriteria)
df_kriteria
# Out:
#                              Emisi CO2 per km (g/km)  \
# Emisi CO2 per km (g/km)                         1.00
# Konsumsi BBM Comb (L/100km)                     0.50
# Konsumsi BBM Hwy (L/100km)                      0.33
# MPG (Miles Per Gallon)                          0.33
# Ukuran Mesin (cc)                               0.20
# Jumlah Silinder                                 0.14
#
#                              Konsumsi BBM Comb (L/100km)  \
# Emisi CO2 per km (g/km)                             2.00
# Konsumsi BBM Comb (L/100km)                         1.00
# Konsumsi BBM Hwy (L/100km)                          0.50
# MPG (Miles Per Gallon)                              0.50
# Ukuran Mesin (cc)                                   0.25
# Jumlah Silinder                                     0.20
#
#                              Konsumsi BBM Hwy (L/100km)  \
# Emisi CO2 per km (g/km)                            3.00
# Konsumsi BBM Comb (L/100km)                        2.00
# Konsumsi BBM Hwy (L/100km)                         1.00
# MPG (Miles Per Gallon)                             0.50
# Ukuran Mesin (cc)                                  0.33
# Jumlah Silinder                                    0.25
#
#                              MPG (Miles Per Gallon)  Ukuran Mesin (cc)  \
# Emisi CO2 per km (g/km)                        3.00                5.0
# Konsumsi BBM Comb (L/100km)                    2.00                4.0
# Konsumsi BBM Hwy (L/100km)                     2.00                3.0
# MPG (Miles Per Gallon)                         1.00                3.0
# Ukuran Mesin (cc)                              0.33                1.0
# Jumlah Silinder                                0.25                0.5
#
#                              Jumlah Silinder
# Emisi CO2 per km (g/km)                  7.0
# Konsumsi BBM Comb (L/100km)              5.0
# Konsumsi BBM Hwy (L/100km)               4.0
# MPG (Miles Per Gallon)                   4.0
# Ukuran Mesin (cc)                        2.0
# Jumlah Silinder                          1.0

# %%
jumlah_kolom = matriks_perbandingan.sum(axis=0)
normalisasi_kriteria = matriks_perbandingan / jumlah_kolom

df_normalisasi = pd.DataFrame(
    np.round(normalisasi_kriteria, 4), 
    columns=kriteria, 
    index=kriteria
)

df_normalisasi
# Out:
#                              Emisi CO2 per km (g/km)  \
# Emisi CO2 per km (g/km)                       0.3985
# Konsumsi BBM Comb (L/100km)                   0.1992
# Konsumsi BBM Hwy (L/100km)                    0.1328
# MPG (Miles Per Gallon)                        0.1328
# Ukuran Mesin (cc)                             0.0797
# Jumlah Silinder                               0.0569
#
#                              Konsumsi BBM Comb (L/100km)  \
# Emisi CO2 per km (g/km)                           0.4494
# Konsumsi BBM Comb (L/100km)                       0.2247
# Konsumsi BBM Hwy (L/100km)                        0.1124
# MPG (Miles Per Gallon)                            0.1124
# Ukuran Mesin (cc)                                 0.0562
# Jumlah Silinder                                   0.0449
#
#                              Konsumsi BBM Hwy (L/100km)  \
# Emisi CO2 per km (g/km)                          0.4235
# Konsumsi BBM Comb (L/100km)                      0.2824
# Konsumsi BBM Hwy (L/100km)                       0.1412
# MPG (Miles Per Gallon)                           0.0706
# Ukuran Mesin (cc)                                0.0471
# Jumlah Silinder                                  0.0353
#
#                              MPG (Miles Per Gallon)  Ukuran Mesin (cc)  \
# Emisi CO2 per km (g/km)                      0.3495             0.3030
# Konsumsi BBM Comb (L/100km)                  0.2330             0.2424
# Konsumsi BBM Hwy (L/100km)                   0.2330             0.1818
# MPG (Miles Per Gallon)                       0.1165             0.1818
# Ukuran Mesin (cc)                            0.0388             0.0606
# Jumlah Silinder                              0.0291             0.0303
#
#                              Jumlah Silinder
# Emisi CO2 per km (g/km)               0.3043
# Konsumsi BBM Comb (L/100km)           0.2174
# Konsumsi BBM Hwy (L/100km)            0.1739
# MPG (Miles Per Gallon)                0.1739
# Ukuran Mesin (cc)                     0.0870
# Jumlah Silinder                       0.0435

# %%
bobot_kriteria = normalisasi_kriteria.mean(axis=1)

df_bobot = pd.DataFrame(
    {'Bobot': np.round(bobot_kriteria, 4),
     'Bobot(%)': np.round(bobot_kriteria * 100, 2)},
    index=kriteria
)
df_bobot
# Out:
#                               Bobot  Bobot(%)
# Emisi CO2 per km (g/km)      0.3714     37.14
# Konsumsi BBM Comb (L/100km)  0.2332     23.32
# Konsumsi BBM Hwy (L/100km)   0.1625     16.25
# MPG (Miles Per Gallon)       0.1313     13.13
# Ukuran Mesin (cc)            0.0616      6.16
# Jumlah Silinder              0.0400      4.00

# %% [markdown]
# ## Mengecek Konsistensi AHP

# %%
n = len(kriteria)
hasil_kali = np.dot(matriks_perbandingan, bobot_kriteria)
lambda_max = np.mean(hasil_kali / bobot_kriteria)
ci = (lambda_max - n) / (n - 1)
ri = 1.24
cr = ci / ri

print(f"Lambda max             : {lambda_max:.4f}")
print(f"Consistency Index (CI) : {ci:.4f}")
print(f"Consistency Ratio (CR) : {cr:.4f}")

if cr < 0.1:
    print("Matriks perbandingan konsisten.")
else:
    print("Matriks perbandingan tidak konsisten. Perlu diperbaiki.")
# Out:
# Lambda max             : 6.1458
# Consistency Index (CI) : 0.0292
# Consistency Ratio (CR) : 0.0235
# Matriks perbandingan konsisten.

# %% [markdown]
# ## Data Penilaian dari Alternatif

# %%
## Persiapan Data Alternatif dari Dataset

# Mapping kolom dataset ke nama kriteria
kolom_dataset = [
    'CO2 Emissions(g/km)',
    'Fuel Consumption Comb (L/100 km)',
    'Fuel Consumption Hwy (L/100 km)',
    'Fuel Consumption Comb (mpg)',
    'Engine Size(L)',
    'Cylinders',
]

# Buat label unik tiap kendaraan (Make + Model + index)
data['Nama_Kendaraan'] = data['Make'] + ' ' + data['Model'] + ' (' + data.index.astype(str) + ')'

# Ambil kolom yang diperlukan dan rename sesuai nama kriteria
data_alternatif = data[['Nama_Kendaraan'] + kolom_dataset].copy()
data_alternatif = data_alternatif.set_index('Nama_Kendaraan')
data_alternatif.columns = kriteria

print(f"Total alternatif kendaraan: {len(data_alternatif)}")
data_alternatif.head()
# Out:
# Total alternatif kendaraan: 7385
#                       Emisi CO2 per km (g/km)  Konsumsi BBM Comb (L/100km)  \
# Nama_Kendaraan
# ACURA ILX (0)                             196                          8.5
# ACURA ILX (1)                             221                          9.6
# ACURA ILX HYBRID (2)                      136                          5.9
# ACURA MDX 4WD (3)                         255                         11.1
# ACURA RDX AWD (4)                         244                         10.6
#
#                       Konsumsi BBM Hwy (L/100km)  MPG (Miles Per Gallon)  \
# Nama_Kendaraan
# ACURA ILX (0)                                6.7                      33
# ACURA ILX (1)                                7.7                      29
# ACURA ILX HYBRID (2)                         5.8                      48
# ACURA MDX 4WD (3)                            9.1                      25
# ACURA RDX AWD (4)                            8.7                      27
#
#                       Ukuran Mesin (cc)  Jumlah Silinder
# Nama_Kendaraan
# ACURA ILX (0)                       2.0                4
# ACURA ILX (1)                       2.4                4
# ACURA ILX HYBRID (2)                1.5                4
# ACURA MDX 4WD (3)                   3.5                6
# ACURA RDX AWD (4)                   3.5                6

# %%
## Normalisasi Data Alternatif (SAW)
# - cost    : min(kolom) / nilai  → nilai kecil = skor mendekati 1
# - benefit : nilai / max(kolom)  → nilai besar = skor mendekati 1
# Khusus BBM Hwy (benefit): tetap pakai min/x karena
#   nilai L/100km kecil = lebih hemat = lebih baik

def normalisasi_saw(df, tipe_kriteria):
    df_norm = df.copy().astype(float)
    for i, col in enumerate(df.columns):
        if tipe_kriteria[i] == 'cost':
            df_norm[col] = df[col].min() / df[col]
        else:  # benefit
            if 'Hwy' in col or 'L/100' in col:
                # Benefit tapi satuan cost (L/100km): balik dengan min/x
                df_norm[col] = df[col].min() / df[col]
            else:
                df_norm[col] = df[col] / df[col].max()
    return df_norm

data_normalisasi = normalisasi_saw(data_alternatif, tipe_kriteria)

print("Data setelah normalisasi (nilai 0-1):")
print("Semua nilai harus berada di rentang 0 hingga 1:")
print(f"  Min: {data_normalisasi.min().min():.4f}")
print(f"  Max: {data_normalisasi.max().max():.4f}")
print()
data_normalisasi.head()
# Out:
# Data setelah normalisasi (nilai 0-1):
# Semua nilai harus berada di rentang 0 hingga 1:
#   Min: 0.1071
#   Max: 1.0000
#                       Emisi CO2 per km (g/km)  Konsumsi BBM Comb (L/100km)  \
# Nama_Kendaraan
# ACURA ILX (0)                        0.489796                     0.482353
# ACURA ILX (1)                        0.434389                     0.427083
# ACURA ILX HYBRID (2)                 0.705882                     0.694915
# ACURA MDX 4WD (3)                    0.376471                     0.369369
# ACURA RDX AWD (4)                    0.393443                     0.386792
#
#                       Konsumsi BBM Hwy (L/100km)  MPG (Miles Per Gallon)  \
# Nama_Kendaraan
# ACURA ILX (0)                           0.597015                0.478261
# ACURA ILX (1)                           0.519481                0.420290
# ACURA ILX HYBRID (2)                    0.689655                0.695652
# ACURA MDX 4WD (3)                       0.439560                0.362319
# ACURA RDX AWD (4)                       0.459770                0.391304
#
#                       Ukuran Mesin (cc)  Jumlah Silinder
# Nama_Kendaraan
# ACURA ILX (0)                  0.450000             0.75
# ACURA ILX (1)                  0.375000             0.75
# ACURA ILX HYBRID (2)           0.600000             0.75
# ACURA MDX 4WD (3)              0.257143             0.50
# ACURA RDX AWD (4)              0.257143             0.50

# %%
## hitung skor akhir dengan metode ahp

skor_akhir = data_normalisasi.dot(bobot_kriteria)

df_hasil = pd.DataFrame({
    'Nama Kendaraan': data_normalisasi.index,
    'Skor Akhir': skor_akhir
}).sort_values(by='Skor Akhir', ascending=False)

# tambahkan data asli untuk referensi
df_hasil['CO2 (g/km)'] = data_alternatif['Emisi CO2 per km (g/km)'].values
df_hasil['Konsumsi BBM Comb (L/100km)'] = data_alternatif['Konsumsi BBM Comb (L/100km)'].values
df_hasil['Konsumsi BBM Hwy (L/100km)'] = data_alternatif['Konsumsi BBM Hwy (L/100km)'].values
df_hasil['MPG (Miles Per Gallon)'] = data_alternatif['MPG (Miles Per Gallon)'].values
df_hasil['Ukuran Mesin (cc)'] = data_alternatif['Ukuran Mesin (cc)'].values
df_hasil['Jumlah Silinder'] = data_alternatif['Jumlah Silinder'].values

# ranking
df_hasil = df_hasil.sort_values(by='Skor Akhir', ascending=False).reset_index(drop=True)
df_hasil.index += 1  # mulai index dari 1 untuk ranking
df_hasil.index.name = 'Ranking'
df_hasil['Ranking'] = df_hasil['Skor Akhir'].rank(ascending=False).astype(int)

print(f"Total kendaraan yang diranking: {len(df_hasil)}")
print("\nTop 20 Kendaraan Rendah Emisi:")
df_hasil.head(20)
# Out:
# Total kendaraan yang diranking: 7385
#
# Top 20 Kendaraan Rendah Emisi:
#                        Nama Kendaraan  Skor Akhir  CO2 (g/km)  \
# Ranking
# 1           HYUNDAI IONIQ BLUE (3824)    0.963067         196
# 2           HYUNDAI IONIQ Blue (6950)    0.963067         221
# 3           HYUNDAI IONIQ Blue (5931)    0.963067         136
# 4           HYUNDAI IONIQ BLUE (4900)    0.963067         255
# 5                HYUNDAI IONIQ (6949)    0.934714         244
# 6                HYUNDAI IONIQ (4899)    0.909889         230
# 7                HYUNDAI IONIQ (5930)    0.903167         232
# 8                HYUNDAI IONIQ (3823)    0.897636         255
# 9                 TOYOTA Prius (6442)    0.880772         267
# 10                TOYOTA PRIUS (3229)    0.877304         212
# 11                TOYOTA PRIUS (5392)    0.874040         225
# 12                TOYOTA PRIUS (4297)    0.874040         239
# 13       TOYOTA Corolla Hybrid (7335)    0.873977         193
# 14                TOYOTA Prius (7341)    0.867829         359
# 15               TOYOTA PRIUS c (993)    0.847360         359
# 16                 KIA NIRO FE (5002)    0.841813         338
# 17                 KIA Niro FE (6026)    0.841813         354
# 18                 KIA Niro FE (7042)    0.841813         338
# 19                 KIA NIRO FE (3934)    0.841813         354
# 20                TOYOTA PRIUS (2113)    0.841204         359
#
#          Konsumsi BBM Comb (L/100km)  Konsumsi BBM Hwy (L/100km)  \
# Ranking
# 1                                8.5                         6.7
# 2                                9.6                         7.7
# 3                                5.9                         5.8
# 4                               11.1                         9.1
# 5                               10.6                         8.7
# 6                               10.0                         7.7
# 7                               10.1                         8.1
# 8                               11.1                         9.0
# 9                               11.6                         9.5
# 10                               9.2                         7.5
# 11                               9.8                         8.1
# 12                              10.4                         8.3
# 13                               8.4                         6.9
# 14                              15.6                        12.6
# 15                              15.6                        12.6
# 16                              14.7                        11.3
# 17                              15.4                        12.2
# 18                              14.7                        11.3
# 19                              15.4                        12.2
# 20                              15.6                        12.6
#
#          MPG (Miles Per Gallon)  Ukuran Mesin (cc)  Jumlah Silinder  Ranking
# Ranking
# 1                            33                2.0                4        2
# 2                            29                2.4                4        2
# 3                            48                1.5                4        2
# 4                            25                3.5                6        2
# 5                            27                3.5                6        5
# 6                            28                3.5                6        6
# 7                            28                3.5                6        7
# 8                            25                3.7                6        8
# 9                            24                3.7                6        9
# 10                           31                2.4                4       10
# 11                           29                2.4                4       11
# 12                           27                3.5                6       11
# 13                           34                1.8                4       13
# 14                           18                5.9               12       14
# 15                           18                5.9               12       15
# 16                           19                4.7                8       17
# 17                           18                4.7                8       17
# 18                           19                4.7                8       17
# 19                           18                4.7                8       17
# 20                           18                5.9               12       20

# %%
# tampilkan rekomendasi top 10

print("╔══════════════════════════════════════════════════════════════════════════╗")
print("║         REKOMENDASI TOP 10 KENDARAAN RENDAH EMISI (AHP)                  ║")
print("╚══════════════════════════════════════════════════════════════════════════╝")
print()

for i, row in df_hasil.head(10).iterrows():
    nama = row['Nama Kendaraan'].rsplit('(', 1)[0]
    print(f"Rank #{i:2d} | {nama}")
    print(f"           Skor Akhir: {row['Skor Akhir']:.4f}")
    print(f"           Emisi CO2: {row['CO2 (g/km)']} g/km")
    print(f"           Konsumsi BBM Comb: {row['Konsumsi BBM Comb (L/100km)']} L/100km")
    print(f"           Konsumsi BBM Hwy: {row['Konsumsi BBM Hwy (L/100km)']} L/100km")
    print(f"           MPG: {row['MPG (Miles Per Gallon)']} mpg")
    print(f"           Ukuran Mesin: {row['Ukuran Mesin (cc)']} cc")
    print(f"           Jumlah Silinder: {row['Jumlah Silinder']}")
    print("-" * 80)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║         REKOMENDASI TOP 10 KENDARAAN RENDAH EMISI (AHP)                  ║
# ╚══════════════════════════════════════════════════════════════════════════╝
#
# Rank # 1 | HYUNDAI IONIQ BLUE
#            Skor Akhir: 0.9631
#            Emisi CO2: 196 g/km
#            Konsumsi BBM Comb: 8.5 L/100km
#            Konsumsi BBM Hwy: 6.7 L/100km
#            MPG: 33 mpg
#            Ukuran Mesin: 2.0 cc
#            Jumlah Silinder: 4
# --------------------------------------------------------------------------------
# Rank # 2 | HYUNDAI IONIQ Blue
#            Skor Akhir: 0.9631
#            Emisi CO2: 221 g/km
#            Konsumsi BBM Comb: 9.6 L/100km
#            Konsumsi BBM Hwy: 7.7 L/100km
#            MPG: 29 mpg
#            Ukuran Mesin: 2.4 cc
#            Jumlah Silinder: 4
# --------------------------------------------------------------------------------
# Rank # 3 | HYUNDAI IONIQ Blue
#            Skor Akhir: 0.9631
#            Emisi CO2: 136 g/km
#            Konsumsi BBM Comb: 5.9 L/100km
#            Konsumsi BBM Hwy: 5.8 L/100km
#            MPG: 48 mpg
#            Ukuran Mesin: 1.5 cc
#            Jumlah Silinder: 4
# --------------------------------------------------------------------------------
# Rank # 4 | HYUNDAI IONIQ BLUE
#            Skor Akhir: 0.9631
#            Emisi CO2: 255 g/km
#            Konsumsi BBM Comb: 11.1 L/100km
#            Konsumsi BBM Hwy: 9.1 L/100km
#            MPG: 25 mpg
#            Ukuran Mesin: 3.5 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank # 5 | HYUNDAI IONIQ
#            Skor Akhir: 0.9347
#            Emisi CO2: 244 g/km
#            Konsumsi BBM Comb: 10.6 L/100km
#            Konsumsi BBM Hwy: 8.7 L/100km
#            MPG: 27 mpg
#            Ukuran Mesin: 3.5 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank # 6 | HYUNDAI IONIQ
#            Skor Akhir: 0.9099
#            Emisi CO2: 230 g/km
#            Konsumsi BBM Comb: 10.0 L/100km
#            Konsumsi BBM Hwy: 7.7 L/100km
#            MPG: 28 mpg
#            Ukuran Mesin: 3.5 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank # 7 | HYUNDAI IONIQ
#            Skor Akhir: 0.9032
#            Emisi CO2: 232 g/km
#            Konsumsi BBM Comb: 10.1 L/100km
#            Konsumsi BBM Hwy: 8.1 L/100km
#            MPG: 28 mpg
#            Ukuran Mesin: 3.5 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank # 8 | HYUNDAI IONIQ
#            Skor Akhir: 0.8976
#            Emisi CO2: 255 g/km
#            Konsumsi BBM Comb: 11.1 L/100km
#            Konsumsi BBM Hwy: 9.0 L/100km
#            MPG: 25 mpg
#            Ukuran Mesin: 3.7 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank # 9 | TOYOTA Prius
#            Skor Akhir: 0.8808
#            Emisi CO2: 267 g/km
#            Konsumsi BBM Comb: 11.6 L/100km
#            Konsumsi BBM Hwy: 9.5 L/100km
#            MPG: 24 mpg
#            Ukuran Mesin: 3.7 cc
#            Jumlah Silinder: 6
# --------------------------------------------------------------------------------
# Rank #10 | TOYOTA PRIUS
#            Skor Akhir: 0.8773
#            Emisi CO2: 212 g/km
#            Konsumsi BBM Comb: 9.2 L/100km
#            Konsumsi BBM Hwy: 7.5 L/100km
#            MPG: 31 mpg
#            Ukuran Mesin: 2.4 cc
#            Jumlah Silinder: 4
# --------------------------------------------------------------------------------

# %%
# simpan hasil ke file csv

df_export = df_hasil.copy()
df_export['Nama Kendaraan'] = df_export['Nama Kendaraan'].str.rsplit('(',n=1).str[0]
df_export.to_csv('hasil_ranking_kendaraan_rendah_emisi.csv')

print("Hasil ranking kendaraan rendah emisi telah disimpan ke 'hasil_ranking_kendaraan_rendah_emisi.csv'")
# Out:
# Hasil ranking kendaraan rendah emisi telah disimpan ke 'hasil_ranking_kendaraan_rendah_emisi.csv'
